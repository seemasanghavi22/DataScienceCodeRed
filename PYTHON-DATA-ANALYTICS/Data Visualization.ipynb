# %% [markdown]
# # Plotting and Visualization in Python
# In this notebook, we will understand usage of Matplotlib, Seaborn and Pandas for creating plots for data insight.

# %% [markdown]
# ### Matplotlib
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
#
# Matplotlib was created by John D. Hunter.
#
# Matplotlib is open source and we can use it freely.
#
# The source code for Matplotlib is located at this github repository https://github.com/matplotlib/matplotlib

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# pip install matplotlib

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.3.4
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: matplotlib-users@python.org
# License: PSF
# Location: c:\users\user\anaconda3\lib\site-packages
# Requires: cycler, kiwisolver, numpy, pillow, pyparsing, python-dateutil
# Required-by: arviz, clust, imgaug, ipympl, missingno, mlxtend, prophet, scikit-image, seaborn, wordcloud, yellowbrick
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### MATPLOT LINE PLOTS

# %% [markdown]
# ##### Draw a line in a diagram from position (0,0) to position (6,250):

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### Draw a line in a diagram from position (2,8) to position (3,10):

# %%
xpoints = np.array([2, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# ##### Default X-Points
# If we do not specify the points on the x-axis, they will get the default values 0, 1, 2, 3 etc., depending on the length of the y-points.

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

# plt.plot(ypoints) 
# plt.plot(ypoints,marker = 'o') #  specify each point with a marker
# plt.plot(ypoints,marker = 'o', ms = 10) #  specify each point with a marker and a specified size for the marker
# plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r') #  specify each point with a marker, a edge color and a size for the marker
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r') #  specify each point with a marker, a fill color and a size for the marker

plt.show()

# %% [markdown]
# ##### Create Labels for a Plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20} # define fonts
font2 = {'family':'serif','color':'darkred','size':15} # define fonts
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5) # adding grid lines with color, a linestyle
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5) # adding grid lines with color, a linestyle
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5) # adding grid lines with color, a linestyle
plt.show()

# %% [markdown]
# ##### Display Multiple Plots using subplot adjacent to each other

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.title('Sales')
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.title('Revenue')
plt.plot(x,y)

plt.suptitle('Sales and Revenue')
plt.show()

# %% [markdown]
# ##### Display Multiple Plots using subplot on each row

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1) #the figure has 2 rows, 1 column, and this plot is the first row plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2) #the figure has 2 rows, 1 column, and this plot is the second row plot.
plt.plot(x,y)

plt.show()

# %% [markdown]
# ##### Exercise - Draw a 5 row plot with random generated data

# %% [markdown]
# #### MATPLOT BAR PLOTS
# Bar plots are useful for displaying and comparing measurable quantities, such as counts or volumes.

# %%
city = np.array(["A", "B", "C", "D"])
growth = np.array([3, 5, 1, 6])

plt.bar(city,growth,color = "red", width = 0.5) # vertical bar
#plt.barh(person,height) # horizontal bar
plt.title('Growth chart',color = "red")
plt.show()

# %%
city = np.array(["A", "B", "C", "D"])
growth = np.array([3, 5, 1, 6])
plt.barh(city,growth,color = "red") # horizontal bar
plt.title('Growth chart',color = "red")
plt.show()

# %% [markdown]
# #### MATPLOT HISTOGRAM PLOTS
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# Histograms are a sort of bar graph that displays relative frequencies of data values; hence, the y-axis is always some measure of frequency. This can either be raw counts of values or scaled proportions.

# %%
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %% [markdown]
# #### MATPLOT piechart PLOTS
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %%
y = np.array([35, 25, 25, 15])
 
mylabels = ["Apples", "Bananas", "Cherries", "Dates"] # adding a Label for the data point
mycolors = ["black", "hotpink", "b", "#4CAF50"] # adding a color
plt.pie(y, labels = mylabels, colors = mycolors)
plt.legend()  # adding a legend with a title
# plt.legend(title = "Four Fruits:")  # adding a legend with a title
plt.show()

# %%
y = np.array([35, 25, 25, 15])
 
mylabels = ["Apples", "Bananas", "Cherries", "Dates"] # adding a Label for the data point
mycolors = ["black", "hotpink", "b", "#4CAF50"] # adding a color
myexplode = [0.2, 0, 0, 0] # bring out the first item
plt.pie(y, labels = mylabels, colors = mycolors, explode = myexplode)
plt.legend()  # adding a legend with a title
# plt.legend(title = "Four Fruits:")  # adding a legend with a title
plt.show()

# %% [markdown]
# #### MATPLOT SCATTER PLOTS

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y, color = 'red')
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Plotting with Pandas

# %%
normals = pd.Series(np.random.normal(size=10))
normals.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Notice that by default a line plot is drawn, and light background is included. These decisions were made on your behalf by pandas.
#
# All of this can be changed, however:

# %%
normals.cumsum().plot(grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Similarly, for a DataFrame:

# %%
variables = pd.DataFrame({'apple': np.random.normal(size=100), 
                       'oranges': np.random.gamma(1, size=100), 
                       'mango': np.random.poisson(size=100)})
variables.cumsum(0).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# As an illustration of the high-level nature of Pandas plots, we can split multiple series into subplots with a single argument for `plot`:

# %%
variables.cumsum(0).plot(subplots=True, grid=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %% [markdown]
# Or, we may want to have some series displayed on the secondary y-axis, which can allow for greater detail and less empty space:

# %%
variables.cumsum(0).plot(secondary_y='normal', grid=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# If we would like a little more control, we can use matplotlib's `subplots` function directly, and manually assign plots to its axes:

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 4))
for i,var in enumerate(['apple','oranges','mango']):
    variables[var].cumsum(0).plot(ax=axes[i], title=var)
axes[0].set_ylabel('cumulative sum')
# Out:
# Text(0, 0.5, 'cumulative sum')

# %% [markdown]
# ## Bar plots

# %%
titanic = pd.read_excel("./data/titanic.xls", "titanic")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic.groupby('pclass').survived.sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby(['sex','pclass']).survived.sum().plot.barh()
# Out:
# <AxesSubplot:ylabel='sex,pclass'>

# %%
death_counts = pd.crosstab([titanic.pclass, titanic.sex], titanic.survived.astype(bool))
death_counts.plot.bar(stacked=True, color=['black','gold'], grid=True)
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %% [markdown]
# Another way of comparing the groups is to look at the survival *rate*, by adjusting for the number of people in each group.

# %%
death_counts.div(death_counts.sum(1).astype(float), axis=0).plot.barh(stacked=True, color=['black','gold'])
# Out:
# <AxesSubplot:ylabel='pclass,sex'>

# %% [markdown]
# ## Histograms
# For example, we might want to see how the fares were distributed aboard the titanic:

# %%
titanic.fare.hist(grid=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# The `hist` method puts the continuous fare values into **bins**, trying to make a sensible décision about how many bins to use (or equivalently, how wide the bins are). We can override the default value (10):

# %%
titanic.fare.hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are algorithms for determining an "optimal" number of bins, each of which varies somehow with the number of observations in the data series.

# %%
from scipy.stats import kurtosis
doanes = lambda data: int(1 + np.log(len(data)) + np.log(1 + kurtosis(data) * (len(data) / 6.) ** 0.5))

n = len(titanic)
doanes(titanic.fare.dropna())
# Out:
# 14

# %%
titanic.fare.hist(bins=doanes(titanic.fare.dropna()))
# Out:
# <AxesSubplot:>

# %% [markdown]
# A **density plot** is similar to a histogram in that it describes the distribution of the underlying data, but rather than being a pure empirical representation, it is an *estimate* of the underlying "true" distribution. As a result, it is smoothed into a continuous line plot. We create them in Pandas using the `plot` method with `kind='kde'`, where `kde` stands for **kernel density estimate**.

# %%
titanic.fare.dropna().plot.kde(xlim=(0,600))
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Often, histograms and density plots are shown together:

# %%
titanic.fare.hist(bins=doanes(titanic.fare.dropna()), density=True, color='lightseagreen')
titanic.fare.dropna().plot.kde(xlim=(0,600), style='r--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Here, we had to normalize the histogram (`density=True`), since the kernel density is normalized by definition (it is a probability distribution).
#
# - `density=True` represents the frequency distribution
# - `density=False` represents the probability density distribution

# %% [markdown]
# ## Boxplots
# A different way of visualizing the distribution of data is the boxplot, which is a display of common quantiles.
#
# It also provides details of outliers in the data attribute.

# %%
titanic.boxplot(column='fare', by='pclass', grid=False)
# Out:
# <AxesSubplot:title={'center':'fare'}, xlabel='pclass'>

# %% [markdown]
# You can think of the box plot as viewing the distribution from above. The blue crosses are "outlier" points that occur outside the extreme quantiles.

# %% [markdown]
# One way to add additional information to a boxplot is to overlay the actual data; this is generally most suitable with small- or moderate-sized data series.

# %%
bp = titanic.boxplot(column='age', by='pclass', grid=False)
for i in [1,2,3]:
    y = titanic.age[titanic.pclass==i].dropna()
    # Add some random "jitter" to the x-axis
    x = np.random.normal(i, 0.04, size=len(y))
    plt.plot(x, y.values, 'r.', alpha=0.2)

# %%
titanic.plot.scatter('age', 'pclass')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='age', ylabel='pclass'>

# %%
titanic.plot.scatter('sex', 'age')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
titanic.plot.scatter('pclass', 'age')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# When data are dense, a couple of tricks used above help the visualization:
#
# 1. reducing the alpha level to make the points partially transparent
# 2. adding random "jitter" along the x-axis to avoid overstriking

# %% [markdown]
# ## Scatterplots <a id='p3.4' />
#
# To look at how Pandas does scatterplots, let's look at a small dataset in wine chemistry.

# %%
# Prepare data 
data={'Name':['Mike', 'Tom', 'Peter', 
              'Mary', 'Felicia', 'Lucy'], 
      'Age':[ 30, 18, 27, 50, 12, 45]} 
  
# Load data into DataFrame 
df = pd.DataFrame(data = data); 
  
# Draw a scatter plot and here size of dots determined by age of person 
df.plot.scatter(x = 'Name', y = 'Age', s = 'Age', c = 'red');

# %%
# Draw a scatter plot and here size of dots determined by age of person 
df.plot.scatter(x = 'Name', y = 'Age', s = df.Age*100, c = 'red', alpha=0.5);

# %%
# Draw a scatter plot and here size of dots determined by age of person 
df.plot.scatter('Name','Age', c = df.Age*100, cmap='hot')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Age'>

# %% [markdown]
# # Plotting with Seaborn

# %% [markdown]
# Seaborn is conventionally imported using the `sns` alias. Simply importing Seaborn invokes the default Seaborn settings. These are generally more muted colors with a light gray background and subtle white grid lines.

# %%
import seaborn as sns

normals.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Customizing Seaborn Figure Aesthetics
#
# Seaborn manages plotting parameters in two general groups:
#
# - setting components of aesthetic style of the plot
# - scaling elements of the figure

# %% [markdown]
# This default theme is called `darkgrid`; there are a handful of preset themes:
#
# - `darkgrid`
# - `whitegrid`
# - `dark`
# - `white`
# - `ticks`
#
# Each are suited to partiular applications. For example, in more "data-heavy" situations, one might want a lighter background.
#
# We can apply an alternate theme using `set_style`:

# %%
sns.set_style('whitegrid')
sns.boxplot(x='pclass', y='age', data=titanic)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
sns.set_style('ticks')
sns.boxplot(x='pclass', y='age', data=titanic)
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %% [markdown]
# The figure still looks heavy, with the axes distracting from the lines in the boxplot. We can remove them with `despine`:

# %%
sns.boxplot(x='pclass', y='age', data=titanic)
sns.despine()

# %% [markdown]
# With `despine`argument, we can specify more space to the plot.
#
# We can move axes away from the figure elements (via `offset`) and minimize the length of the axes to the lowest and highest major tick value (via `trim`):

# %%
sns.boxplot(x='pclass', y='age', data=titanic)
sns.despine(offset=20, trim=True)

# %% [markdown]
# The second set of figure aesthetic parameters controls the scale of the plot elements.
#
# There are four default scales that correspond to different **contexts** that a plot may be intended for use with.
#
# - `paper`
# - `notebook`
# - `talk`
# - `poster`
#
# The default is `notebook`, which is optimized for use in Jupyter notebooks. We can change the scaling with `set_context`:

# %%
sns.set_context('paper')

sns.boxplot(x='pclass', y='age', data=titanic)
sns.despine(offset=20, trim=True)

# %%
sns.set_context('poster')

sns.boxplot(x='pclass', y='age', data=titanic)
sns.despine(offset=20, trim=True)

# %% [markdown]
# Each of the contexts can be fine-tuned for more specific applications:

# %%
sns.set_context('notebook', font_scale=0.5, rc={'lines.linewidth': 0.5})

sns.boxplot(x='pclass', y='age', data=titanic)
sns.despine(offset=20, trim=True)

# %% [markdown]
# The detailed settings are available in the `plotting.context`:

# %%
sns.plotting_context()
# Out:
# {'font.size': 6.0,
#  'axes.labelsize': 6.0,
#  'axes.titlesize': 6.0,
#  'xtick.labelsize': 5.5,
#  'ytick.labelsize': 5.5,
#  'legend.fontsize': 5.5,
#  'axes.linewidth': 1.25,
#  'grid.linewidth': 1.0,
#  'lines.linewidth': 0.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 1.25,
#  'ytick.major.width': 1.25,
#  'xtick.minor.width': 1.0,
#  'ytick.minor.width': 1.0,
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 4.0,
#  'ytick.minor.size': 4.0,
#  'legend.title_fontsize': 6.0}

# %%
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
data.head()
# Out:
#           x         y
# 0  0.559335 -1.374657
# 1  5.735801  2.010009
# 2 -1.649663  0.362650
# 3  0.515172  2.708931
# 4 -2.481303 -1.639963

# %% [markdown]
# ##### Generate kernel density estimates of two sets of simulated data, via the `kdeplot` function.

# %%
sns.set()

for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %% [markdown]
# ##### Generate a `distplot` to combine a kernel density estimate and a histogram.

# %%
sns.distplot(data['x'])
# Out:
# <AxesSubplot:xlabel='x', ylabel='Density'>

# %% [markdown]
# ##### Generate a `kdeplot` with two columns of data

# %%
sns.kdeplot(data=data, x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
